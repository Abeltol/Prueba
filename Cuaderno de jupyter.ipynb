# %% [markdown]
# #My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ##**José Alberto Hernández Laurel**
# ##Científico de datos

# %% [markdown]
# ###*Estoy interesado en la ciencia de datos porque me gusta la forma en como se puede usar de una manera mas efectiva la información*

# %% [markdown]
# ###El condigo muestra la fecha del dia de hoy

# %%
from datetime import date
today = date.today()
print(today)
# Out:
# 2022-08-01

# %% [markdown]
# ---
# *Viñeta A
# *viñeta B
#
# 1. Lista numerada 1
# 2. Lista numerada 2
#
# Image(url=jupyter.png)
#
#  \_Ejemplo de resaltado\_
#
#  ~~Este campo esta tachado~~
